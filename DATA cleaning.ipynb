# %%
import pandas as pd
import numpy as np
import string
import re




df = pd.read_csv('DATA/USelection2024.csv')
df
# Out:
#                     author      published_at        updated_at  like_count  \
# 0      @ivanrafaelsoto5829  10/30/2024 20:02  10/30/2024 20:02           0
# 1             @Susan-i3p7r  10/30/2024 20:01  10/30/2024 20:01           0
# 2          @unclerandy1023  10/30/2024 19:56  10/30/2024 19:56           0
# 3             @ikerluz2220  10/30/2024 19:49  10/30/2024 19:49           0
# 4           @snakeeyes4424  10/30/2024 19:47  10/30/2024 19:47           0
# ...                    ...               ...               ...         ...
# 33298     @noahbrooksphoto   10/30/2024 4:28   10/30/2024 4:28           1
# 33299            @vueone27   10/30/2024 4:28   10/30/2024 4:28          12
# 33300          @blue-tb6uv   10/30/2024 4:27   10/30/2024 4:27           5
# 33301      @critterjon4061   10/30/2024 4:26   10/30/2024 4:36           3
# 33302       @Just4this-g9m   10/30/2024 4:24   10/30/2024 4:25           0
#
# ...

# %%
def clean_text(text):
    # Remove hyperlinks
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Convert text to lowercase
    text = text.lower()

    return text
def remove_emojis(text):
    # Regular expression pattern to match emojis
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # Emoticons
        "\U0001F300-\U0001F5FF"  # Symbols & Pictographs
        "\U0001F680-\U0001F6FF"  # Transport & Map Symbols
        "\U0001F1E0-\U0001F1FF"  # Flags
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols & Pictographs
        "\U0001F600-\U0001F64F"  # Additional emoticons
        "\U00002600-\U000026FF"  # Miscellaneous Symbols (e.g., sun, star)
        "\U00002700-\U000027BF"  # Dingbats
        "\U0001F680-\U0001F6FF"  # Transport & Map symbols
        "\U0001F700-\U0001F77F"  # Alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U0001FB00-\U0001FBFF"  # Symbols for Legacy Computing
        "]+",
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# %%
# Clean the text data
df['cleaned_text'] = df['text'].apply(clean_text)

# Remove emojis
df['cleaned_text'] = df['cleaned_text'].apply(remove_emojis)
# code to remove "@" from author names
df['author'] = df['author'].str.replace('@', '', regex=False)

# Export the cleaned text to a new CSV file
df[['author','like_count', 'cleaned_text','hashtags']].to_csv('cleaned_text_data.csv', index=False)

# Display the first few rows to confirm
print(df[['author','like_count', 'cleaned_text','hashtags']].head())
# Out:
#                author  like_count  \
# 0  ivanrafaelsoto5829           0
# 1         Susan-i3p7r           0
# 2      unclerandy1023           0
# 3         ikerluz2220           0
# 4       snakeeyes4424           0
#
#                                         cleaned_text    hashtags
# 0                                     very fake news  Trumprally
# 1      but biden can call millions of people garbage  Trumprally
# 2   i want to know what aoc has done for puerto rico  Trumprally
# 3                more people need to know about this  Trumprally
# 4  no sitting president in the whole history of u...  Trumprally
